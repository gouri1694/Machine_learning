# %% [markdown]
# ## MLflow Introduction

# %% [markdown]
# ### What is MLflow?
#
# MLflow is an open source platform for managing the machine learning lifecycle from start to finish.
#
# MLflow is organized into four components:
# - Tracking,
# - Projects,
# - Models, and
# - Model Registry
# Each of these components can be used independently. That means we can still track the model’s performance without exporting models in MLflow’s model format.
#
# MLflow is designed to put as few constraints as possible and make codebase written in its format reproducible and reusable by multiple data scientists.

# %% [markdown]
# ### MLflow Components
# ![image.png](attachment:ce432cb3-04df-4780-be4d-b3a59bb5dfff.png)

# %% [markdown]
# MLflow can integrates with tensorflow, pytorch, keras, spark,sklearn, hugging face,Monai, Rapids, python, R, Java,ONNX,Docker, ..etc

# %% [markdown]
# ### Installation and first trial of MLflow
# - First create the conda environment by the following command

# %%
conda create --prefix ./env python=3.7 -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\Documents\19June2022\env
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.5.18.1        |   py37haa95532_0         157 KB
#     openssl-1.1.1o             |       h2bbff1b_0         4.8 MB
#     ------------------------------------------------------------
#                                            Total:         5.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-2022.4.26-haa95532_0
#   certifi            pkgs/main/win-64::certifi-2022.5.18.1-py37haa95532_0
#   openssl            pkgs/main/win-64::openssl-1.1.1o-h2bbff1b_0
#   pip                pkgs/main/win-64::pip-21.2.4-py37haa95532_0
#   python             pkgs/main/win-64::python-3.7.13-h6244533_0
#   setuptools         pkgs/main/win-64::setuptools-61.2.0-py37haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.38.3-h2bbff1b_0
#   vc                 pkgs/main/win-64::vc-14.2-h21ff451_1
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.27.29016-h5e58377_2
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   wincertstore       pkgs/main/win-64::wincertstore-0.2-py37haa95532_2
#
#
#
# Downloading and Extracting Packages
#
# certifi-2022.5.18.1  | 157 KB    |            |   0%
# certifi-2022.5.18.1  | 157 KB    | #          |  10%
# certifi-2022.5.18.1  | 157 KB    | ########## | 100%
# certifi-2022.5.18.1  | 157 KB    | ########## | 100%
#
# openssl-1.1.1o       | 4.8 MB    |            |   0%
# openssl-1.1.1o       | 4.8 MB    | ##8        |  28%
# openssl-1.1.1o       | 4.8 MB    | #######    |  71%
# openssl-1.1.1o       | 4.8 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate C:\Users\DELL\Documents\19June2022\env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %% [markdown]
# - activate environment

# %%
conda activate ./env
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - To use MLflow as a Python library, install it using pip. You can install MLflow by running:

# %%
pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-1.26.1-py3-none-any.whl (17.8 MB)
# Collecting Flask
#   Downloading Flask-2.1.2-py3-none-any.whl (95 kB)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.37-cp310-cp310-win_amd64.whl (1.6 MB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (6.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (21.3)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (2022.1)
# Collecting waitress
#   Downloading waitress-2.1.2-py3-none-any.whl (57 kB)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (1.4.2)
# Collecting importlib-metadata!=4.7.0,>=3.7.0
#   Using cached importlib_metadata-4.11.4-py3-none-any.whl (18 kB)
# Collecting querystring-parser
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.17.0.tar.gz (81 kB)
# Requirement already satisfied: requests>=2.17.3 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (2.27.1)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (1.8.1)
# Collecting gitpython>=2.1.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (1.22.4)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.20.2-py3-none-any.whl (18 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-4.21.1-cp310-abi3-win_amd64.whl (524 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting cloudpickle
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow) (0.4)
# Collecting alembic
#   Downloading alembic-1.8.0-py3-none-any.whl (209 kB)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from click>=7.0->mlflow) (0.4.4)
# Collecting pyjwt>=1.7.0
#   Downloading PyJWT-2.4.0-py3-none-any.whl (18 kB)
# Collecting oauthlib>=3.1.0
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting tabulate>=0.7.7
#   Using cached tabulate-0.8.9-py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.10.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from databricks-cli>=0.8.7->mlflow) (1.16.0)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.2-py2.py3-none-any.whl (145 kB)
#   Downloading docker-5.0.1-py2.py3-none-any.whl (145 kB)
#   Using cached docker-5.0.0-py2.py3-none-any.whl (146 kB)
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
#   Downloading docker-4.4.3-py2.py3-none-any.whl (146 kB)
#   Downloading docker-4.4.2-py2.py3-none-any.whl (146 kB)
#   Downloading docker-4.4.1-py2.py3-none-any.whl (146 kB)
#   Downloading docker-4.4.0-py2.py3-none-any.whl (146 kB)
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
#   Downloading docker-4.3.0-py2.py3-none-any.whl (145 kB)
#   Downloading docker-4.2.2-py2.py3-none-any.whl (144 kB)
# Collecting pypiwin32==223
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from docker>=4.0.0->mlflow) (1.3.2)
# Requirement already satisfied: pywin32>=223 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from pypiwin32==223->docker>=4.0.0->mlflow) (304)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow) (2.0.12)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.2-cp310-cp310-win_amd64.whl (101 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Flask->mlflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Jinja2>=3.0->Flask->mlflow) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from packaging->mlflow) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from pandas->mlflow) (2.8.2)
# Requirement already satisfied: prometheus-client in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from prometheus-flask-exporter->mlflow) (0.14.1)
# Building wheels for collected packages: databricks-cli
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.0-py3-none-any.whl size=141954 sha256=b425ffce4c32e7f5a8834d3d79075e99b60e9902919dafb74aa85de3802a3c8f
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\75\20\11\0dacd60061960ae0e80025a0d7a36137c0e95e95dc1d9a93b0
# Successfully built databricks-cli
# Installing collected packages: Werkzeug, smmap, itsdangerous, greenlet, click, zipp, tabulate, sqlalchemy, pypiwin32, pyjwt, oauthlib, Mako, gitdb, Flask, waitress, sqlparse, querystring-parser, protobuf, prometheus-flask-exporter, importlib-metadata, gitpython, docker, databricks-cli, cloudpickle, alembic, mlflow
# Successfully installed Flask-2.1.2 Mako-1.2.0 Werkzeug-2.1.2 alembic-1.8.0 click-8.1.3 cloudpickle-2.1.0 databricks-cli-0.17.0 docker-4.2.2 gitdb-4.0.9 gitpython-3.1.27 greenlet-1.1.2 importlib-metadata-4.11.4 itsdangerous-2.1.2 mlflow-1.26.1 oauthlib-3.2.0 prometheus-flask-exporter-0.20.2 protobuf-4.21.1 pyjwt-2.4.0 pypiwin32-223 querystring-parser-1.2.4 smmap-5.0.0 sqlalchemy-1.4.37 sqlparse-0.4.2 tabulate-0.8.9 waitress-2.1.2 zipp-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Running a Sample App With the Tracking API
# The programs "demo_mlflow.py" use the MLflow Tracking API. For instance, run: demo_mlflow.py.<br>
# This program will use MLflow Tracking API, which logs tracking data in ./mlruns. This can then be viewed with the Tracking UI.

# %%
run demo_mlflow.py

# %% [markdown]
# ### Launching the Tracking UI
# The MLflow Tracking UI will show runs logged in ./mlruns at http://localhost:5000. Start it with:<br>
# **mlflow ui**

# %% [markdown]
# new window pops up
# ![image.png](attachment:25ac1845-f90f-444a-a54f-c8744ada4f84.png)<br>
# It will record all our runs with all required details

# %%
cd simple_ML_Model
# Out:
# C:\Users\DELL\Documents\19June2022\simple_ML_Model

# %%
conda create --prefix ./env python=3.7 -y
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\Documents\19June2022\simple_ML_Model\env
#
#   added / updated specs:
#     - python=3.7
#
#
# The following NEW packages will be INSTALLED:
#
#   ca-certificates    pkgs/main/win-64::ca-certificates-2022.4.26-haa95532_0
#   certifi            pkgs/main/win-64::certifi-2022.5.18.1-py37haa95532_0
#   openssl            pkgs/main/win-64::openssl-1.1.1o-h2bbff1b_0
#   pip                pkgs/main/win-64::pip-21.2.4-py37haa95532_0
#   python             pkgs/main/win-64::python-3.7.13-h6244533_0
#   setuptools         pkgs/main/win-64::setuptools-61.2.0-py37haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.38.3-h2bbff1b_0
#   vc                 pkgs/main/win-64::vc-14.2-h21ff451_1
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.27.29016-h5e58377_2
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0
#   wincertstore       pkgs/main/win-64::wincertstore-0.2-py37haa95532_2
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate C:\Users\DELL\Documents\19June2022\simple_ML_Model\env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.13.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda activate ./env
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Documents\\19June2022'

# %%
cd simple_ML_model
# Out:
# C:\Users\DELL\Documents\19June2022\simple_ML_model

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Documents\\19June2022\\simple_ML_model'

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: mlflow in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from -r requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from -r requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: pandas in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from -r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: entrypoints in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: alembic in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: sqlalchemy in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.4.37)
# Requirement already satisfied: databricks-cli>=0.8.7 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: pytz in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: requests>=2.17.3 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.27.1)
# Requirement already satisfied: numpy in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.22.4)
# Requirement already satisfied: Flask in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: querystring-parser in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (1.2.4)
# Requirement already satisfied: waitress in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: prometheus-flask-exporter in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (0.20.2)
# Requirement already satisfied: protobuf>=3.12.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (4.21.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (6.0)
# Requirement already satisfied: gitpython>=2.1.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (3.1.27)
# Requirement already satisfied: click>=7.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: cloudpickle in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: docker>=4.0.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (4.2.2)
# Requirement already satisfied: importlib-metadata!=4.7.0,>=3.7.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (4.11.4)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from mlflow->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from scikit-learn->-r requirements.txt (line 2)) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from click>=7.0->mlflow->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: oauthlib>=3.1.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: tabulate>=0.7.7 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements.txt (line 1)) (0.8.9)
# Requirement already satisfied: pyjwt>=1.7.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from databricks-cli>=0.8.7->mlflow->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pypiwin32==223 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements.txt (line 1)) (223)
# Requirement already satisfied: websocket-client>=0.32.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from docker>=4.0.0->mlflow->-r requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: pywin32>=223 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from pypiwin32==223->docker>=4.0.0->mlflow->-r requirements.txt (line 1)) (304)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from gitpython>=2.1.0->mlflow->-r requirements.txt (line 1)) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow->-r requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from importlib-metadata!=4.7.0,>=3.7.0->mlflow->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 1)) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 1)) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from requests>=2.17.3->mlflow->-r requirements.txt (line 1)) (2.0.12)
# Requirement already satisfied: Mako in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from alembic->mlflow->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from sqlalchemy->mlflow->-r requirements.txt (line 1)) (1.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Flask->mlflow->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Flask->mlflow->-r requirements.txt (line 1)) (3.1.2)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Flask->mlflow->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from Jinja2>=3.0->Flask->mlflow->-r requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from packaging->mlflow->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: prometheus-client in c:\users\dell\anaconda3\envs\dl\lib\site-packages (from prometheus-flask-exporter->mlflow->-r requirements.txt (line 1)) (0.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Documents\\19June2022\\simple_ML_model'

# %%
run simple_ML_Model.py
# Out:
# Elastic net params: alpha: 0.5, l1_ratio: 0.5
# Elastic net metric: rmse:0.6911571350850594, mae: 0.5550938596747247, r2:0.15667145170374475
# C:\Users\DELL\anaconda3\envs\dl\lib\site-packages\_distutils_hack\__init__.py:30: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")

# %%
run simple_ML_Model.py -a 0.7 -l1 0.6
# Out:
# Elastic net params: alpha: 0.7, l1_ratio: 0.6
# Elastic net metric: rmse:0.7938976117282213, mae: 0.6510106098028734, r2:0.03298927097882909

# %%
run simple_ML_Model.py -a 0.4 -l1 0.6
# Out:
# Elastic net params: alpha: 0.4, l1_ratio: 0.6
# Elastic net metric: rmse:0.6851632978696311, mae: 0.5711918117983461, r2:0.16947556740328573

# %%
run simple_ML_Model.py -a 0.3 -l1 0.7
# Out:
# Elastic net params: alpha: 0.3, l1_ratio: 0.7
# Elastic net metric: rmse:0.716639212946033, mae: 0.5794403689384892, r2:0.18347825981651156

# %% [markdown]
# visualize or Tracking UI

# %% [markdown]
# <code>
# **run can be done in this fashion as well.**
#
# import numpy as np
# import os
# alpha_s=np.linspace(0.1, 1.0, 5)
# l1_ratios=np.linspace(0.1, 1.0, 5)
# for alpha in alpha_s:
#     for l1 in l1_ratios:
#         os.system(f"python simple_ML_model_2.py -a {alpha} -l1 {l1}")
# <code>

# %% [markdown]
# ### Packaging a project MLflow way

# %% [markdown]
# - Create a conda.yaml file as shown below:
# <code>
# conda.yaml
# name: mlflow_tutorial
# channels:
#     - defaults
# dependencies:
#     - python=3.7.11=h6244533_0
#     - pip=21.2.4=py37haa95532_0
#     - pip:
#         - mlflow==1.23.1
#         - numpy==1.21.5
#         - pandas==1.3.5
#         - scikit-learn==1.0.2<code>

# %% [markdown]
# - or run the following command to create conda.yaml file
# <code>
# conda env export > conda.yaml
#
# Note:
# make sure you are in the same environment while running the command whose conda.yaml file you wish to create
# <code>

# %% [markdown]
# - after above step create the an MLproject file in the root of the project as shown below -
# <code>
# MLproject
# name: mlflow_tutorial
# conda_env: conda.yaml
# entry_points:
#     main:
#         parameters:
#             alpha: {type: float, default: 0.5}
#             l1_ratio: {type: float, default: 0.5}
#         command: "python simple_ML_model_2.py -a {alpha} -l1 {l1_ratio}"<code>

# %% [markdown]
# - Now run the following command to execte the project
# <code>
#     * without using a fresh conda environment by using the existing environment-
#         mlflow run . --no-conda
#     * with a fresh conda environment -
#         mlflow run .
#     * if you wish to pass command line argument then use the below command-
#         mlflow run . -P alpha=0.7 -P l1_ratio=0.4 <code>
